# %%
Q1: What is Matplotlib? Why is it used? Name 5 plots that can be plotted using the Pyplot module ofMatplotlib.

# %%
it is a python linrary used to create static,animated and interactive visualisation.
its is easy to use  and have the ability to handlecomplex visualization

Matplotlib is Used beacause it is 
Versatility:It can create a wide range of visualizations.
Customization: Provides extensive options to customize the appearance of plots.
Integration: Works well with other Python libraries like NumPy, Pandas, and SciPy, and integrates seamlessly with Jupyter Notebooks.
Interactive: Supports interactive plotting, allowing for dynamic updates to plots.
Publication Quality: Capable of producing high-quality figures suitable for publication.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=[1, 2, 3, 4]
y=[10, 20, 25, 30]
plt.plot(x, y)
plt.title('Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
x=['1','2','3','4','5']
y=np.random.rand(5)
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
x=np.random.rand(105)
y=np.random.rand(105)
colour=np.random.rand(105)
size=500*np.random.rand(105)
plt.scatter(x,y,c=colour,alpha=.8,s=size)

# %%
x = 'A', 'B', 'C', 'D'
y = [15, 30, 45, 10]
plt.pie(y, labels=x, autopct='%1.1f%%')
plt.title('Pie Chart')
plt.show()

# %%
import matplotlib.pyplot as plt
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
plt.hist(data, bins=4)
plt.title('Histogram')
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.show()

# %%
Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.

Note: Also add title, xlabel, and ylabel to the plot.

# %%
A scatter plot is a type of plot that displays values for two variables as a collection of points. Each point 
represents an observation in the dataset, with the position on the x-axis representing one variable and the
position on the y-axis representing the other. Scatter plots are useful for identifying relationships between 
two variables.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x, y)
plt.title('Scatter Plot of Generated Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
The subplot() function in Matplotlib is used to create multiple plots in a single figure. It allows you to 
arrange multiple subplots in a grid-like pattern,making it easier to compare different plots side by side .

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.plot(x1, y1)
plt.title('Line Plot 1')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.subplot(2, 2, 2)
plt.plot(x2, y2)
plt.title('Line Plot 2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.subplot(2, 2, 3)
plt.plot(x3, y3)
plt.title('Line Plot 3')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.subplot(2, 2, 4)
plt.plot(x4, y4)
plt.title('Line Plot 4')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.tight_layout()
plt.show()

# %%
Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
A bar plot, is a type of chart that presents categorical data with rectangular bars. Each bar's length is
proportional to the value it represents. Bar plots can be displayed vertically or horizontally.
Bar Plot is used for
Comparison of Categories: Bar plots are use for  comparing different categories or groups. They provide a clear
visual representation of data, making it easy to see which categories are larger or smaller.
Clarity: They are easy to understand and interpret, making them suitable for audiences without specialized
knowledge.
Data Presentation: They are useful for presenting data in a way that is easy to compare across different groups
Highlighting Differences: Bar plots can effectively highlight significant differences or trends in data across 
different categories.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
A box plot, also known as a whisker plot, is a standardized way of displaying the distribution of data based on
a 5-number summary: minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum. 
It may also highlight outliers.
a Box Plot Used 
Distribution Summary: it provides a visual summary of the data distribution, highlighting the median,
quartiles, and potential outliers.
Comparison: Box plots are effective for comparing distributions between multiple groups or datasets.
Outlier Detection: They help identify outliers that deviate significantly from the rest of the data.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = [box1, box2]

plt.boxplot(data, patch_artist=True, notch=True, vert=True, labels=['Box1', 'Box2'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f45a41e8460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f45a41e89a0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7f45a41e80d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f45a41e8ee0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f45a41e9180>,
# ...
#  'means': []}
